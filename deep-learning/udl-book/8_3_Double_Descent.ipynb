# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers of size 100
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  # create 100 dummy data points and store in data loader class
  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose()).type(torch.LongTensor)
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test']).type(torch.LongTensor)

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      y_batch = y_batch.type(torch.LongTensor)
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.300380, train error 88.85,  test loss 2.300885, test error 89.38
# Epoch   100, train loss 1.929997, train error 72.85,  test loss 1.764740, test error 69.90
# Epoch   200, train loss 1.917675, train error 72.20,  test loss 1.750901, test error 69.43
# Epoch   300, train loss 1.915273, train error 70.75,  test loss 1.746479, test error 69.72
# Epoch   400, train loss 1.914619, train error 71.12,  test loss 1.744729, test error 69.20
# Epoch   500, train loss 1.913801, train error 70.85,  test loss 1.741768, test error 69.30
# Epoch   600, train loss 1.913468, train error 70.75,  test loss 1.743502, test error 69.28
# Epoch   700, train loss 1.913760, train error 70.95,  test loss 1.741040, test error 68.80
# Epoch   800, train loss 1.913536, train error 71.10,  test loss 1.738956, test error 68.80
# Epoch   900, train loss 1.913456, train error 70.90,  test loss 1.739047, test error 68.70
# Training model with   4 hidden variables
# Epoch     0, train loss 2.240732, train error 81.93,  test loss 2.223108, test error 80.38
# Epoch   100, train loss 1.786676, train error 65.97,  test loss 1.624967, test error 64.43
# Epoch   200, train loss 1.773757, train error 66.38,  test loss 1.609455, test error 63.92
# Epoch   300, train loss 1.773001, train error 65.50,  test loss 1.619591, test error 63.62
# Epoch   400, train loss 1.763744, train error 64.85,  test loss 1.613166, test error 63.58
# Epoch   500, train loss 1.760838, train error 65.05,  test loss 1.613026, test error 63.17
# Epoch   600, train loss 1.763901, train error 65.03,  test loss 1.620791, test error 63.42
# Epoch   700, train loss 1.757885, train error 64.82,  test loss 1.616983, test error 63.78
# Epoch   800, train loss 1.759592, train error 64.88,  test loss 1.627196, test error 63.55
# Epoch   900, train loss 1.756518, train error 65.03,  test loss 1.623187, test error 63.65
# Training model with   6 hidden variables
# Epoch     0, train loss 2.276949, train error 88.22,  test loss 2.279232, test error 87.90
# Epoch   100, train loss 1.755996, train error 63.10,  test loss 1.630232, test error 62.72
# Epoch   200, train loss 1.680657, train error 58.42,  test loss 1.533639, test error 58.17
# Epoch   300, train loss 1.640435, train error 55.55,  test loss 1.481980, test error 55.03
# Epoch   400, train loss 1.581888, train error 54.25,  test loss 1.413072, test error 52.00
# Epoch   500, train loss 1.574029, train error 53.95,  test loss 1.394606, test error 52.08
# Epoch   600, train loss 1.564462, train error 53.62,  test loss 1.393141, test error 51.72
# Epoch   700, train loss 1.558439, train error 53.53,  test loss 1.391334, test error 51.35
# Epoch   800, train loss 1.559414, train error 53.67,  test loss 1.394739, test error 52.00
# Epoch   900, train loss 1.566594, train error 53.62,  test loss 1.410997, test error 52.72
# Training model with   8 hidden variables
# Epoch     0, train loss 2.283953, train error 86.93,  test loss 2.283628, test error 87.20
# Epoch   100, train loss 1.539838, train error 51.60,  test loss 1.338748, test error 48.47
# Epoch   200, train loss 1.485703, train error 50.15,  test loss 1.299299, test error 47.08
# Epoch   300, train loss 1.478012, train error 49.22,  test loss 1.308798, test error 47.70
# Epoch   400, train loss 1.459145, train error 49.53,  test loss 1.315235, test error 47.97
# Epoch   500, train loss 1.454529, train error 48.88,  test loss 1.314550, test error 47.55
# Epoch   600, train loss 1.459687, train error 49.65,  test loss 1.326866, test error 48.35
# Epoch   700, train loss 1.450488, train error 48.72,  test loss 1.321200, test error 47.95
# Epoch   800, train loss 1.448114, train error 48.75,  test loss 1.326967, test error 48.15
# Epoch   900, train loss 1.447710, train error 48.92,  test loss 1.334327, test error 48.58
# Training model with  10 hidden variables
# Epoch     0, train loss 2.233534, train error 82.62,  test loss 2.221004, test error 81.93
# Epoch   100, train loss 1.609588, train error 55.75,  test loss 1.468435, test error 56.08
# Epoch   200, train loss 1.546485, train error 52.65,  test loss 1.448197, test error 55.03
# Epoch   300, train loss 1.514307, train error 52.08,  test loss 1.447571, test error 54.33
# Epoch   400, train loss 1.498593, train error 51.08,  test loss 1.460936, test error 52.97
# Epoch   500, train loss 1.487904, train error 50.55,  test loss 1.461061, test error 53.30
# Epoch   600, train loss 1.475231, train error 50.15,  test loss 1.461820, test error 53.45
# Epoch   700, train loss 1.475904, train error 50.55,  test loss 1.473277, test error 53.03
# Epoch   800, train loss 1.469658, train error 50.00,  test loss 1.470540, test error 53.60
# Epoch   900, train loss 1.466120, train error 50.28,  test loss 1.467954, test error 53.15
# Training model with  14 hidden variables
# Epoch     0, train loss 2.257314, train error 84.15,  test loss 2.249409, test error 82.28
# Epoch   100, train loss 1.460090, train error 48.38,  test loss 1.350101, test error 50.12
# Epoch   200, train loss 1.346675, train error 44.88,  test loss 1.278340, test error 46.67
# Epoch   300, train loss 1.298930, train error 42.92,  test loss 1.287884, test error 47.10
# Epoch   400, train loss 1.284147, train error 42.70,  test loss 1.328606, test error 47.28
# Epoch   500, train loss 1.275678, train error 42.60,  test loss 1.345011, test error 47.25
# Epoch   600, train loss 1.265529, train error 42.30,  test loss 1.349479, test error 47.97
# Epoch   700, train loss 1.263279, train error 42.62,  test loss 1.363845, test error 48.55
# Epoch   800, train loss 1.258709, train error 41.53,  test loss 1.371755, test error 49.00
# Epoch   900, train loss 1.266076, train error 42.30,  test loss 1.386601, test error 48.65
# Training model with  18 hidden variables
# Epoch     0, train loss 2.180168, train error 80.50,  test loss 2.135819, test error 79.50
# Epoch   100, train loss 1.415302, train error 47.80,  test loss 1.386788, test error 51.35
# Epoch   200, train loss 1.266007, train error 42.72,  test loss 1.375450, test error 49.97
# Epoch   300, train loss 1.243483, train error 42.22,  test loss 1.437259, test error 50.53
# Epoch   400, train loss 1.205677, train error 41.28,  test loss 1.428147, test error 50.25
# Epoch   500, train loss 1.193841, train error 40.92,  test loss 1.466035, test error 51.42
# Epoch   600, train loss 1.197495, train error 40.80,  test loss 1.495774, test error 51.28
# Epoch   700, train loss 1.174678, train error 40.20,  test loss 1.518855, test error 51.45
# Epoch   800, train loss 1.170805, train error 40.85,  test loss 1.532929, test error 51.78
# Epoch   900, train loss 1.159314, train error 39.83,  test loss 1.564829, test error 52.38
# Training model with  22 hidden variables
# Epoch     0, train loss 2.186710, train error 81.25,  test loss 2.156120, test error 79.88
# Epoch   100, train loss 1.278845, train error 42.28,  test loss 1.300864, test error 47.95
# Epoch   200, train loss 1.166006, train error 38.42,  test loss 1.370203, test error 48.65
# Epoch   300, train loss 1.101391, train error 36.75,  test loss 1.449117, test error 49.72
# Epoch   400, train loss 1.056968, train error 35.65,  test loss 1.513550, test error 50.12
# Epoch   500, train loss 1.041846, train error 34.28,  test loss 1.565282, test error 50.72
# Epoch   600, train loss 1.039677, train error 35.10,  test loss 1.634481, test error 50.47
# Epoch   700, train loss 0.997112, train error 32.85,  test loss 1.657415, test error 51.17
# Epoch   800, train loss 0.992962, train error 33.57,  test loss 1.701568, test error 51.83
# Epoch   900, train loss 0.987506, train error 33.35,  test loss 1.748256, test error 50.97
# Training model with  26 hidden variables
# Epoch     0, train loss 2.118215, train error 78.32,  test loss 2.077146, test error 77.82
# Epoch   100, train loss 1.206623, train error 40.55,  test loss 1.402691, test error 52.10
# Epoch   200, train loss 1.055121, train error 36.25,  test loss 1.529625, test error 53.28
# Epoch   300, train loss 0.990152, train error 33.70,  test loss 1.632644, test error 54.75
# Epoch   400, train loss 0.942479, train error 32.22,  test loss 1.732879, test error 54.35
# Epoch   500, train loss 0.910486, train error 31.53,  test loss 1.780183, test error 54.65
# Epoch   600, train loss 0.916374, train error 31.85,  test loss 1.862156, test error 56.05
# Epoch   700, train loss 0.884304, train error 30.65,  test loss 1.900448, test error 54.80
# Epoch   800, train loss 0.871058, train error 30.40,  test loss 1.946692, test error 55.47
# Epoch   900, train loss 0.858358, train error 29.47,  test loss 2.018970, test error 55.50
# Training model with  30 hidden variables
# Epoch     0, train loss 2.132548, train error 79.28,  test loss 2.099677, test error 78.43
# Epoch   100, train loss 1.141892, train error 37.38,  test loss 1.364177, test error 48.92
# Epoch   200, train loss 0.970022, train error 32.03,  test loss 1.543628, test error 50.72
# Epoch   300, train loss 0.879880, train error 29.53,  test loss 1.702816, test error 52.00
# Epoch   400, train loss 0.841001, train error 28.30,  test loss 1.886675, test error 52.03
# Epoch   500, train loss 0.798204, train error 27.53,  test loss 2.029761, test error 53.35
# Epoch   600, train loss 0.788075, train error 26.47,  test loss 2.192551, test error 54.25
# Epoch   700, train loss 0.751089, train error 25.80,  test loss 2.340000, test error 54.30
# Epoch   800, train loss 0.743830, train error 25.30,  test loss 2.477148, test error 55.03
# Epoch   900, train loss 0.713402, train error 24.22,  test loss 2.635757, test error 55.90
# Training model with  35 hidden variables
# Epoch     0, train loss 2.096508, train error 78.05,  test loss 2.032243, test error 78.25
# Epoch   100, train loss 1.057140, train error 35.12,  test loss 1.433785, test error 50.95
# Epoch   200, train loss 0.852653, train error 28.55,  test loss 1.744582, test error 52.30
# Epoch   300, train loss 0.740043, train error 25.15,  test loss 2.115876, test error 55.97
# Epoch   400, train loss 0.642986, train error 22.18,  test loss 2.365890, test error 55.45
# Epoch   500, train loss 0.622885, train error 22.07,  test loss 2.715423, test error 56.38
# Epoch   600, train loss 0.552210, train error 19.55,  test loss 2.960440, test error 56.03
# Epoch   700, train loss 0.539317, train error 19.18,  test loss 3.238115, test error 56.50
# Epoch   800, train loss 0.531943, train error 18.60,  test loss 3.643613, test error 57.72
# Epoch   900, train loss 0.519762, train error 18.47,  test loss 3.854872, test error 57.67
# Training model with  40 hidden variables
# Epoch     0, train loss 2.108925, train error 80.22,  test loss 2.038861, test error 78.12
# Epoch   100, train loss 0.972455, train error 31.68,  test loss 1.453144, test error 50.88
# Epoch   200, train loss 0.663742, train error 20.80,  test loss 1.982331, test error 53.80
# Epoch   300, train loss 0.547723, train error 18.47,  test loss 2.591721, test error 55.03
# Epoch   400, train loss 0.433293, train error 13.38,  test loss 3.217951, test error 56.08
# Epoch   500, train loss 0.380900, train error 12.62,  test loss 3.889328, test error 57.17
# Epoch   600, train loss 0.336588, train error 10.40,  test loss 4.483078, test error 57.50
# Epoch   700, train loss 0.290712, train error 9.32,  test loss 5.207551, test error 58.50
# Epoch   800, train loss 0.288812, train error 10.18,  test loss 5.945358, test error 59.08
# Epoch   900, train loss 0.281694, train error 9.60,  test loss 6.509311, test error 58.78
# Training model with  45 hidden variables
# Epoch     0, train loss 2.165386, train error 79.95,  test loss 2.132703, test error 79.47
# Epoch   100, train loss 0.832467, train error 27.20,  test loss 1.451115, test error 49.80
# Epoch   200, train loss 0.498255, train error 16.38,  test loss 2.183536, test error 53.28
# Epoch   300, train loss 0.359504, train error 12.68,  test loss 3.248676, test error 55.12
# Epoch   400, train loss 0.250933, train error 8.28,  test loss 4.424733, test error 55.00
# Epoch   500, train loss 0.173378, train error 5.12,  test loss 5.594275, test error 56.15
# Epoch   600, train loss 0.183227, train error 6.43,  test loss 6.564956, test error 55.60
# Epoch   700, train loss 0.038920, train error 0.30,  test loss 7.695706, test error 55.70
# Epoch   800, train loss 0.016852, train error 0.03,  test loss 8.816471, test error 56.22
# Epoch   900, train loss 0.136160, train error 5.05,  test loss 8.528631, test error 56.08
# Training model with  50 hidden variables
# Epoch     0, train loss 2.080374, train error 76.97,  test loss 2.042374, test error 77.53
# Epoch   100, train loss 0.729651, train error 22.62,  test loss 1.572647, test error 50.30
# Epoch   200, train loss 0.372703, train error 10.70,  test loss 2.621780, test error 54.35
# Epoch   300, train loss 0.158041, train error 3.50,  test loss 4.094210, test error 55.95
# Epoch   400, train loss 0.051502, train error 0.28,  test loss 5.710153, test error 55.15
# Epoch   500, train loss 0.015388, train error 0.00,  test loss 6.758338, test error 55.60
# Epoch   600, train loss 0.009479, train error 0.00,  test loss 7.434448, test error 55.83
# Epoch   700, train loss 0.006711, train error 0.00,  test loss 7.934160, test error 56.15
# Epoch   800, train loss 0.005082, train error 0.00,  test loss 8.320164, test error 56.08
# Epoch   900, train loss 0.004087, train error 0.00,  test loss 8.642956, test error 56.17
# Training model with  55 hidden variables
# Epoch     0, train loss 2.165830, train error 79.93,  test loss 2.114807, test error 78.38
# Epoch   100, train loss 0.653831, train error 20.07,  test loss 1.637114, test error 51.42
# Epoch   200, train loss 0.226660, train error 5.15,  test loss 2.912771, test error 53.90
# Epoch   300, train loss 0.050328, train error 0.12,  test loss 4.713405, test error 55.15
# Epoch   400, train loss 0.016579, train error 0.00,  test loss 5.818314, test error 55.42
# Epoch   500, train loss 0.009610, train error 0.00,  test loss 6.477104, test error 55.33
# Epoch   600, train loss 0.006400, train error 0.00,  test loss 6.952649, test error 55.47
# Epoch   700, train loss 0.004777, train error 0.00,  test loss 7.325866, test error 55.78
# Epoch   800, train loss 0.003750, train error 0.00,  test loss 7.623605, test error 55.78
# Epoch   900, train loss 0.003074, train error 0.00,  test loss 7.875260, test error 55.83
# Training model with  60 hidden variables
# Epoch     0, train loss 2.070180, train error 76.50,  test loss 2.005420, test error 75.07
# Epoch   100, train loss 0.507358, train error 14.55,  test loss 1.820519, test error 51.80
# Epoch   200, train loss 0.108823, train error 1.68,  test loss 3.592852, test error 53.88
# Epoch   300, train loss 0.016664, train error 0.00,  test loss 4.820668, test error 53.72
# Epoch   400, train loss 0.008442, train error 0.00,  test loss 5.478693, test error 53.90
# Epoch   500, train loss 0.005505, train error 0.00,  test loss 5.916833, test error 54.22
# Epoch   600, train loss 0.003955, train error 0.00,  test loss 6.240152, test error 54.38
# Epoch   700, train loss 0.003036, train error 0.00,  test loss 6.502290, test error 54.50
# Epoch   800, train loss 0.002459, train error 0.00,  test loss 6.719586, test error 54.70
# Epoch   900, train loss 0.002049, train error 0.00,  test loss 6.903396, test error 54.80
# Training model with  70 hidden variables
# Epoch     0, train loss 2.048046, train error 76.57,  test loss 1.994080, test error 76.28
# Epoch   100, train loss 0.377304, train error 9.20,  test loss 1.995527, test error 53.92
# Epoch   200, train loss 0.032236, train error 0.00,  test loss 3.816188, test error 55.53
# Epoch   300, train loss 0.010656, train error 0.00,  test loss 4.640168, test error 55.60
# Epoch   400, train loss 0.005935, train error 0.00,  test loss 5.116986, test error 55.72
# Epoch   500, train loss 0.003985, train error 0.00,  test loss 5.432786, test error 55.60
# Epoch   600, train loss 0.002949, train error 0.00,  test loss 5.675607, test error 55.60
# Epoch   700, train loss 0.002313, train error 0.00,  test loss 5.875268, test error 55.55
# Epoch   800, train loss 0.001891, train error 0.00,  test loss 6.039170, test error 55.38
# Epoch   900, train loss 0.001589, train error 0.00,  test loss 6.181881, test error 55.40
# Training model with  80 hidden variables
# Epoch     0, train loss 2.003781, train error 74.47,  test loss 1.929552, test error 74.85
# Epoch   100, train loss 0.233612, train error 4.45,  test loss 2.176453, test error 52.40
# Epoch   200, train loss 0.019417, train error 0.00,  test loss 3.601615, test error 54.08
# Epoch   300, train loss 0.007854, train error 0.00,  test loss 4.182974, test error 54.22
# Epoch   400, train loss 0.004625, train error 0.00,  test loss 4.525044, test error 54.33
# Epoch   500, train loss 0.003207, train error 0.00,  test loss 4.768096, test error 54.40
# Epoch   600, train loss 0.002415, train error 0.00,  test loss 4.959679, test error 54.35
# Epoch   700, train loss 0.001917, train error 0.00,  test loss 5.114056, test error 54.38
# Epoch   800, train loss 0.001578, train error 0.00,  test loss 5.245914, test error 54.55
# Epoch   900, train loss 0.001335, train error 0.00,  test loss 5.356709, test error 54.53
# Training model with  90 hidden variables
# Epoch     0, train loss 2.026440, train error 75.25,  test loss 1.943747, test error 74.90
# Epoch   100, train loss 0.147318, train error 1.05,  test loss 2.263836, test error 52.75
# Epoch   200, train loss 0.014886, train error 0.00,  test loss 3.430337, test error 52.90
# Epoch   300, train loss 0.006481, train error 0.00,  test loss 3.889124, test error 52.70
# Epoch   400, train loss 0.003979, train error 0.00,  test loss 4.175457, test error 52.90
# Epoch   500, train loss 0.002797, train error 0.00,  test loss 4.381631, test error 52.88
# Epoch   600, train loss 0.002134, train error 0.00,  test loss 4.541835, test error 52.83
# Epoch   700, train loss 0.001705, train error 0.00,  test loss 4.675456, test error 52.72
# Epoch   800, train loss 0.001413, train error 0.00,  test loss 4.787240, test error 52.70
# Epoch   900, train loss 0.001200, train error 0.00,  test loss 4.882504, test error 52.72
# Training model with 100 hidden variables
# Epoch     0, train loss 2.003101, train error 73.78,  test loss 1.919522, test error 72.97
# Epoch   100, train loss 0.094739, train error 0.18,  test loss 2.239131, test error 52.03
# Epoch   200, train loss 0.012373, train error 0.00,  test loss 3.072636, test error 50.60
# Epoch   300, train loss 0.005777, train error 0.00,  test loss 3.428146, test error 50.90
# Epoch   400, train loss 0.003603, train error 0.00,  test loss 3.655235, test error 50.75
# Epoch   500, train loss 0.002570, train error 0.00,  test loss 3.817811, test error 50.72
# Epoch   600, train loss 0.001966, train error 0.00,  test loss 3.945399, test error 50.70
# Epoch   700, train loss 0.001581, train error 0.00,  test loss 4.051432, test error 50.85
# Epoch   800, train loss 0.001314, train error 0.00,  test loss 4.141553, test error 50.83
# Epoch   900, train loss 0.001119, train error 0.00,  test loss 4.219117, test error 50.90
# Training model with 120 hidden variables
# Epoch     0, train loss 1.992819, train error 73.57,  test loss 1.910456, test error 72.95
# Epoch   100, train loss 0.049163, train error 0.00,  test loss 2.378758, test error 52.80
# Epoch   200, train loss 0.009377, train error 0.00,  test loss 3.020361, test error 52.40
# Epoch   300, train loss 0.004669, train error 0.00,  test loss 3.316195, test error 52.30
# Epoch   400, train loss 0.002991, train error 0.00,  test loss 3.506440, test error 52.25
# Epoch   500, train loss 0.002159, train error 0.00,  test loss 3.644129, test error 52.28
# Epoch   600, train loss 0.001669, train error 0.00,  test loss 3.757174, test error 52.33
# Epoch   700, train loss 0.001349, train error 0.00,  test loss 3.848747, test error 52.47
# Epoch   800, train loss 0.001125, train error 0.00,  test loss 3.926688, test error 52.47
# Epoch   900, train loss 0.000962, train error 0.00,  test loss 3.995691, test error 52.50
# Training model with 140 hidden variables
# Epoch     0, train loss 1.977772, train error 72.55,  test loss 1.914865, test error 73.82
# Epoch   100, train loss 0.035277, train error 0.00,  test loss 2.236197, test error 50.08
# Epoch   200, train loss 0.008002, train error 0.00,  test loss 2.731628, test error 49.85
# Epoch   300, train loss 0.004102, train error 0.00,  test loss 2.965727, test error 50.08
# Epoch   400, train loss 0.002671, train error 0.00,  test loss 3.121486, test error 50.22
# Epoch   500, train loss 0.001942, train error 0.00,  test loss 3.236733, test error 50.40
# Epoch   600, train loss 0.001510, train error 0.00,  test loss 3.328012, test error 50.42
# Epoch   700, train loss 0.001226, train error 0.00,  test loss 3.404293, test error 50.45
# Epoch   800, train loss 0.001028, train error 0.00,  test loss 3.469241, test error 50.45
# Epoch   900, train loss 0.000881, train error 0.00,  test loss 3.526069, test error 50.55
# Training model with 160 hidden variables
# Epoch     0, train loss 1.956364, train error 71.65,  test loss 1.862835, test error 72.05
# Epoch   100, train loss 0.029090, train error 0.00,  test loss 2.179643, test error 49.85
# Epoch   200, train loss 0.007305, train error 0.00,  test loss 2.604445, test error 49.38
# Epoch   300, train loss 0.003843, train error 0.00,  test loss 2.807137, test error 49.50
# Epoch   400, train loss 0.002519, train error 0.00,  test loss 2.945901, test error 49.72
# Epoch   500, train loss 0.001844, train error 0.00,  test loss 3.046258, test error 49.83
# Epoch   600, train loss 0.001439, train error 0.00,  test loss 3.126714, test error 49.80
# Epoch   700, train loss 0.001172, train error 0.00,  test loss 3.194567, test error 49.88
# Epoch   800, train loss 0.000983, train error 0.00,  test loss 3.252206, test error 49.83
# Epoch   900, train loss 0.000844, train error 0.00,  test loss 3.302350, test error 49.90
# Training model with 180 hidden variables
# Epoch     0, train loss 1.917880, train error 69.82,  test loss 1.833681, test error 71.80
# Epoch   100, train loss 0.023981, train error 0.00,  test loss 2.095084, test error 49.12
# Epoch   200, train loss 0.006512, train error 0.00,  test loss 2.460439, test error 48.60
# Epoch   300, train loss 0.003491, train error 0.00,  test loss 2.641020, test error 48.78
# Epoch   400, train loss 0.002309, train error 0.00,  test loss 2.765110, test error 48.75
# Epoch   500, train loss 0.001700, train error 0.00,  test loss 2.859100, test error 48.83
# Epoch   600, train loss 0.001331, train error 0.00,  test loss 2.933558, test error 48.85
# Epoch   700, train loss 0.001087, train error 0.00,  test loss 2.995823, test error 48.88
# Epoch   800, train loss 0.000914, train error 0.00,  test loss 3.048718, test error 48.83
# Epoch   900, train loss 0.000786, train error 0.00,  test loss 3.094762, test error 49.00
# Training model with 200 hidden variables
# Epoch     0, train loss 1.926596, train error 70.38,  test loss 1.814839, test error 69.82
# Epoch   100, train loss 0.020925, train error 0.00,  test loss 2.043323, test error 48.42
# Epoch   200, train loss 0.006067, train error 0.00,  test loss 2.360409, test error 48.20
# Epoch   300, train loss 0.003307, train error 0.00,  test loss 2.526634, test error 48.08
# Epoch   400, train loss 0.002203, train error 0.00,  test loss 2.638214, test error 48.00
# Epoch   500, train loss 0.001629, train error 0.00,  test loss 2.722668, test error 47.97
# Epoch   600, train loss 0.001281, train error 0.00,  test loss 2.790370, test error 47.88
# Epoch   700, train loss 0.001048, train error 0.00,  test loss 2.846480, test error 47.85
# Epoch   800, train loss 0.000883, train error 0.00,  test loss 2.894831, test error 47.80
# Epoch   900, train loss 0.000760, train error 0.00,  test loss 2.937021, test error 47.72
# Training model with 250 hidden variables
# Epoch     0, train loss 1.908566, train error 69.05,  test loss 1.845799, test error 72.05
# Epoch   100, train loss 0.016674, train error 0.00,  test loss 2.017140, test error 48.58
# Epoch   200, train loss 0.005232, train error 0.00,  test loss 2.285348, test error 48.38
# Epoch   300, train loss 0.002921, train error 0.00,  test loss 2.425286, test error 48.20
# Epoch   400, train loss 0.001976, train error 0.00,  test loss 2.522899, test error 48.20
# Epoch   500, train loss 0.001471, train error 0.00,  test loss 2.598329, test error 48.30
# Epoch   600, train loss 0.001162, train error 0.00,  test loss 2.658365, test error 48.08
# Epoch   700, train loss 0.000955, train error 0.00,  test loss 2.709089, test error 48.35
# Epoch   800, train loss 0.000806, train error 0.00,  test loss 2.752172, test error 48.30
# Epoch   900, train loss 0.000696, train error 0.00,  test loss 2.789829, test error 48.33
# Training model with 300 hidden variables
# Epoch     0, train loss 1.872772, train error 66.78,  test loss 1.806142, test error 70.45
# Epoch   100, train loss 0.014174, train error 0.00,  test loss 1.954534, test error 48.67
# Epoch   200, train loss 0.004756, train error 0.00,  test loss 2.182860, test error 48.45
# Epoch   300, train loss 0.002700, train error 0.00,  test loss 2.307572, test error 48.45
# Epoch   400, train loss 0.001839, train error 0.00,  test loss 2.392646, test error 48.40
# Epoch   500, train loss 0.001377, train error 0.00,  test loss 2.459028, test error 48.38
# Epoch   600, train loss 0.001091, train error 0.00,  test loss 2.512449, test error 48.45
# Epoch   700, train loss 0.000898, train error 0.00,  test loss 2.557289, test error 48.30
# Epoch   800, train loss 0.000760, train error 0.00,  test loss 2.596019, test error 48.35
# Epoch   900, train loss 0.000657, train error 0.00,  test loss 2.629890, test error 48.45
# Training model with 400 hidden variables
# Epoch     0, train loss 1.865657, train error 67.05,  test loss 1.769419, test error 68.43
# Epoch   100, train loss 0.011574, train error 0.00,  test loss 1.820979, test error 46.50
# Epoch   200, train loss 0.004136, train error 0.00,  test loss 2.010264, test error 46.47
# Epoch   300, train loss 0.002397, train error 0.00,  test loss 2.112563, test error 46.60
# Epoch   400, train loss 0.001650, train error 0.00,  test loss 2.183870, test error 46.53
# Epoch   500, train loss 0.001244, train error 0.00,  test loss 2.238226, test error 46.50
# Epoch   600, train loss 0.000991, train error 0.00,  test loss 2.282569, test error 46.35
# Epoch   700, train loss 0.000818, train error 0.00,  test loss 2.320215, test error 46.35
# Epoch   800, train loss 0.000695, train error 0.00,  test loss 2.352281, test error 46.35
# Epoch   900, train loss 0.000601, train error 0.00,  test loss 2.380593, test error 46.40

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No. hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
